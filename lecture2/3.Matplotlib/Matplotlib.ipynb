# %%
#github repository sync in google colab
import os
try:
  # Colab only
  # !git clone https://github.com/hukim1112/DLCV_CLASS.git
  os.chdir('/content/DLCV_CLASS/lecture2/3.Matplotlib')      
except Exception:
  pass

# %% [markdown]
# # Matplotlib : python data visualization

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## 선 그래프

# %%
x = np.arange(1,10)
y = x*5
print (x)
print (y)
# Out:
# [1 2 3 4 5 6 7 8 9]
# [ 5 10 15 20 25 30 35 40 45]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## 색깔

# %%
plt.plot(x,y,color='red')
plt.show()

# %% [markdown]
# ![title](matplotlib_color.png)

# %% [markdown]
# ## 마커(데이터 위치)

# %%
plt.plot(x,y,color='red',marker='^')
plt.show()

# %% [markdown]
# ![title](matplotlib_marker.png)

# %% [markdown]
# ## 선 스타일

# %%
plt.plot(x,y,color='red',marker='^',linestyle='--')
plt.show()

# %% [markdown]
# ![title](matplotlib_linestyle.png)

# %% [markdown]
# ## 기타 스타일

# %% [markdown]
# ![title](matplotlib_etc.png)

# %%
# y = x 그래프를 그리시오. (선 색 : green, 선 굵기 : 0.5, 마커 종류 : circle)

# %% [markdown]
# ## 레이블과 제목

# %%
plt.plot(x,y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('y = 5x')
plt.show()

# %% [markdown]
# ## 축 범위

# %%
plt.plot(x,y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('y = 5x')
plt.xlim(0, 10)
plt.ylim(0, 50)
plt.show()

# %% [markdown]
# ## 틱

# %%
plt.plot(x,y)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('y = 5x')
plt.xticks(np.arange(10), ['zero','one','two']) # tick label
plt.yticks(np.arange(50, step=5))
plt.xlim(0, 10)
plt.ylim(0, 50)
plt.show()

# %% [markdown]
# ## 범례

# %%
x = np.linspace(-np.pi, np.pi, 256)
cosine = np.cos(x)
sine = np.sin(x)
plt.plot(x, cosine, ls="--", label="cosine")
plt.plot(x, sine, ls=":", label="sine")
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ![title](matplotlib_legend.png)

# %% [markdown]
# ## 다음 그래프를 그리시오
# ![title](prac1.png)

# %%
# Type your code here

# %% [markdown]
# ## Matplotlib 그림의 구조
# - Figure : 그림이 그려지는 캔버스 또는 종이
# - Axes : 하나의 plot (한 개 이상)
# - Axis : 가로축 or 세로축 (두 개 이상)

# %% [markdown]
# ![title](matplotlib_image.png)

# %% [markdown]
# ## How to add axes?
# ###### Method 1) add_axes([left, bottom, width, height) : the axes object is positioned in absolute coordinates
# ###### Method 2) add_subplot(# of row, # of cols, plot #) : the axes to be situated according to a subplot grid

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.scatter(np.linspace(0, 1, 5), np.linspace(0, 5, 5))

plt.show()

# %%
fig = plt.figure()

ax = fig.add_subplot(111)
ax.scatter(np.linspace(0, 1, 5), np.linspace(0, 5, 5))

plt.show()

# %%
fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1]) # 위치 (0, 0)
ax1.scatter(np.linspace(0, 1, 5), np.linspace(0, 5, 5))

ax2 = fig.add_axes([0.5,0.5,2,2]) # 위치 (0.5, 0.5)
ax2.scatter(np.linspace(0, 2, 10), np.linspace(0, 10, 10))

plt.show()

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2,2,2)
ax1.scatter(np.linspace(0, 1, 5), np.linspace(0, 5, 5))

ax2 = fig.add_subplot(2,2,3)
ax2.scatter(np.linspace(0, 2, 10), np.linspace(0, 10, 10))

plt.show()

# %% [markdown]
# ## How To Change The Size of Figures

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ax1.bar([1,2,3],[3,4,5])
ax2.barh([0.5,1,2.5],[0,1,2])

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,10))

ax1.bar([1,2,3],[3,4,5])
ax2.barh([0.5,1,2.5],[0,1,2])

plt.show()

# %% [markdown]
# ## Options

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,10))

ax1.bar([1,2,3],[3,4,5], color='r')
ax1.set_title('vertical bar plot')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.legend(['axes1'])
ax1.set_ylim([0,10])

ax2.barh([0.5,1,2.5],[0,1,2], color='g')
ax2.set_title('horizontal bar plot')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.legend(['axes2'])
ax2.set_xlim([0,3])

plt.show()
fig.savefig('test.png')

# %% [markdown]
# ## Image

# %%
img = plt.imread('cat.jpg')
plt.imshow(img)

# %%
# 다음 그래프를 그리시오 정답
x = np.linspace(-40, 40, 1000)
y1 = x ** 2
y2 = 50 * x
plt.plot(x, y1, c='red', ls="-", label="y=x^2")
plt.plot(x, y2, c='blue', ls=":", label="y=50x")
plt.ylim(-200, 1000)
plt.legend(loc=0)
plt.show()
